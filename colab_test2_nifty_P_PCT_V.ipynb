# %% [markdown]
# <a href="https://colab.research.google.com/github/yashuvishnalia/tensorflow-basic-test-code/blob/master/colab_test2_nifty_P_PCT_V.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import os
os.listdir('/content/gdrive/My Drive/Colab Notebooks/')
# Out:
# ['Copy of first_steps_with_tensor_flow.ipynb',
#  'Untitled0.ipynb',
#  'colab_test0_nifty.ipynb',
#  'modified_intraday_2017_niftyAllData4-10.pkl',
#  'colab_test1_nifty.ipynb',
#  'colab_test2_nifty.ipynb']

# %%
from __future__ import print_function
import pandas as pd

print(pd.__version__)

panel = pd.read_pickle(r'/content/gdrive/My Drive/Colab Notebooks/\
modified_intraday_2017_niftyAllData4-10.pkl')#,parse_dates=[1])#,date_parser=True)#index_col=False)--not working
panel
# Out:
# 0.23.4
# <class 'pandas.core.panel.Panel'>
# Dimensions: 101 (items) x 89280 (major_axis) x 5 (minor_axis)
# Items axis: ACC to ZEEL
# Major_axis axis: 2017-01-02 04:01:00+00:00 to 2017-12-29 10:00:00+00:00
# Minor_axis axis: open to volume

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import LSTM,Dense, Activation,Dropout

# For custom metrics
import keras.backend as K

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from sklearn import preprocessing
# Out:
# Using TensorFlow backend.

# %%
scaler=preprocessing.MinMaxScaler()
panel['HINDUNILVR'].head()
# Out:
#                              open    high     low   close  volume
# 2017-01-02 04:01:00+00:00  823.60  823.80  823.25  823.75  1699.0
# 2017-01-02 04:02:00+00:00  824.35  825.50  824.30  824.65   365.0
# 2017-01-02 04:03:00+00:00  825.00  825.65  824.80  825.05   324.0
# 2017-01-02 04:04:00+00:00  824.90  825.00  824.30  824.45   564.0
# 2017-01-02 04:05:00+00:00  824.50  825.60  824.50  825.60   385.0

# %%
# callbacks = [
#   # Interrupt training if `val_loss` stops improving for over 2 epochs
#   tf.keras.callbacks.EarlyStopping(patience=2, monitor='val_loss'),
#   # Write TensorBoard logs to `./logs` directory
#   tf.keras.callbacks.TensorBoard(log_dir='./logs')
# ]

# %%
def train(df,batch_size=32,back_step=1,forward=1):
  df['PCT_change']=((df['close']-df['open'])/df['open'])*100
  df['HL_PCT']= ((df['high']-df['low'])/df['close'])*100
  df_=df[['close','volume','PCT_change','HL_PCT']]
  df_['pct']=df['close'].pct_change()
  new_order = [0,4,1,2,3]
  df_=df_[df_.columns[new_order]]
  df_.fillna(0,inplace=True)
  print(df_.head())

  data_=np.array(df_)[0:10000]#change no. of data examples

  global scaler
  scaler=scaler.fit(data_)
  data = scaler.transform(data_)
  mc = keras.callbacks.ModelCheckpoint('best_model.h5', monitor='loss', mode='min', save_best_only=True,verbose=1)
  early_stop = keras.callbacks.EarlyStopping(monitor='loss',mode='min', verbose=1,patience=50)#,baseline=4.2307e-04,#monitor='val_loss'
# could use early_stop and mc in a list(it will save best model and stop after patience=50)
               
  
  def feature_and_label(X,y,back_step=1,forward_step=1):
      X_ = np.array([X[i:i+back_step][:] for i in range(len(X)-back_step+1-forward_step)])#index(0-1009)=len1010
      #for continuous data prediction
  #     y_ = np.array([y[i+back_step:i+back_step+forward_step] 
  #                    for i in range(len(y)-back_step+1-forward_step)])#index(1-1010)=len1010
      #prediction at forward_step 
      y_ = np.array([y[i+back_step+forward_step-1] 
                     for i in range(len(y)-back_step+1-forward_step)])    
      return X_,y_
  def data_prep(data_t,back_step=1,forward=1,batch_size=32):
      ''' change data_t[:,1:2],data_t[:,0] accordingly '''
      X_,y_ = feature_and_label(data_t[:,0:3],data_t[:,0],back_step,forward)
      X_=X_.reshape(len(X_),len(X_[0]),len(X_[0][0]))
      y_=y_.reshape(len(y_),1)#have to change if we have other dimen of y
      print("shape X, y : ",X_.shape,y_.shape,X_[0],y_[0])

      m=int(len(X_)/batch_size)
      ratio=(int(m*0.8))*batch_size
      train_X,test_X=X_[:ratio],X_[ratio:m*batch_size]
      train_y,test_y=y_[:ratio],y_[ratio:m*batch_size]
      print("test x,y and train x, y shape : ",test_X.shape,test_y.shape,train_X.shape,train_y.shape)

      return train_X,train_y,test_X,test_y

  train_X,train_y,test_X,test_y = \
  data_prep(data_t=data,back_step=back_step,forward=1,batch_size=batch_size)
  
  def build_neural_net(batch_size,back_step=1,n_feature=1):
    # expected input data shape: (batch_size, timesteps, data_dim)
    model = Sequential()
    model.add(LSTM(128, return_sequences=True,batch_input_shape=(batch_size,back_step, n_feature),
                   stateful=True,))  # returns a sequence of vectors of dimension 32
    model.add(Dropout(0.1))
    model.add(LSTM(256))#, return_sequences=True, stateful=True,))  # returns a sequence of vectors of dimension 32
#     model.add(LSTM())  # return a single vector of dimension 32
    model.add(Dropout(0.1))
    model.add(Dense(64))
    model.add(Dense(1))
#     def mean_pred(y_true, y_pred):
#         return K.mean(y_pred)

    # For a mean squared error regression problem
    model.compile(optimizer='adam',
                  loss='mse',
                 metrics=['mae'])# accuracy for regression model doesn't matter
    return model
  def train_(train_X,train_y,back_step,n_feature=1,batch_size=32,model=False):
      if not model:
          model = build_neural_net(batch_size,back_step,n_feature)
      model.fit(train_X,train_y,
            batch_size=batch_size, epochs=80, shuffle=False, verbose=0,
                      callbacks=[mc],
  #           validation_data=(x_val, y_val)
               )
      return model
  model = train_(train_X,train_y,back_step,n_feature=3,batch_size=batch_size)
  return model,train_X,train_y,test_X,test_y

# %%
def plot_graph(model,pred,test_y,best_model_bool=False):
  global scaler
  global ticker
  def scale_for_c_price(scaler=scaler):
      scale=preprocessing.MinMaxScaler()
      scale.min_,scale.scale_=scaler.min_[0],scaler.scale_[0]
      return scale
  scale = scale_for_c_price()
  p=scale.inverse_transform(pred)
  y=scale.inverse_transform(test_y)
  def price_plot(p=p,y=y,ticker=ticker):
      plt.figure(figsize=(15,4))
      plt.plot(range(len(pred)),p,label='p')
      plt.plot(range(len(test_y)),y,label='y')
      plt.title('model for 3 feature(p,pct,v) and 100 epoch for {}'.format(ticker))
      plt.ylabel('price')
      plt.xlabel('minute')
      plt.grid()
      plt.legend()
      plt.show()
      return p,y
  price_plot()
  p=p[:200].reshape(-1)
  y=y[:200].reshape(-1)
  df_yp=pd.DataFrame({'p':p,'y':y})
  df_yp['diff']=df_yp['y']-df_yp['p']
  def loss_plot(model=model):
    model_dict = model.history.history
    np_loss=np.array(model_dict['loss'])
    np_loss = np.sqrt(np_loss)
    plt.plot(np_loss)
    plt.ylabel('rmse loss')
    plt.xlabel('epoch')
    plt.grid()
    plt.show()
    print('minumum loss: {} '.format(np.amin(np_loss)))
    print('at epoch : {}'.format(np.where(np_loss==np.amin(np_loss))))
  if not best_model_bool:
    loss_plot()
  print(df_yp.describe())
  def diff_plot(df_yp=df_yp):
    plt.figure(figsize=(15,5))
    plt.title('graph for first 200 minutes')
    ax1 = plt.subplot2grid((3, 3), (0, 0), rowspan=2,colspan=3)
    ax2 = plt.subplot2grid((3, 3), (2, 0), colspan=3)

    ax1.plot(df_yp.index,df_yp.y,label='y')
    ax1.plot(df_yp.index,df_yp.p,label='p')
    ax2.bar(df_yp.index,df_yp['diff'])
    ax1.grid()
    ax2.grid()
    ax2.set_xlabel('time (m)')
    ax2.set_ylabel('Error')
    ax1.legend()
    plt.show()
  diff_plot()
  return df_yp

# %%
ticker='INFY'
df=panel[ticker]
# df['date'] = pd.to_datetime(df['date'],utc=True)
# df.set_index('date',inplace=True)
df.head(3)#,df.index.dtype
# Out:
#                               open     high      low   close  volume
# 2017-01-02 04:01:00+00:00  1005.25  1006.35  1005.20  1005.4  2517.0
# 2017-01-02 04:02:00+00:00  1005.65  1006.65  1005.55  1005.6  2523.0
# 2017-01-02 04:03:00+00:00  1005.65  1006.90  1005.25  1006.9  1850.0

# %%
model,train_X,train_y,test_X,test_y=train(df,batch_size=64,back_step=1,forward=1)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#                             close       pct  volume  PCT_change    HL_PCT
# 2017-01-02 04:01:00+00:00  1005.4  0.000000  2517.0    0.014922  0.114382
# 2017-01-02 04:02:00+00:00  1005.6  0.000199  2523.0   -0.004972  0.109387
# 2017-01-02 04:03:00+00:00  1006.9  0.001293  1850.0    0.124298  0.163869
# 2017-01-02 04:04:00+00:00  1007.3  0.000397  2512.0    0.029791  0.079420
# 2017-01-02 04:05:00+00:00  1007.7  0.000397  1964.0    0.019851  0.099236
# shape X, y :  (9999, 1, 3) (9999, 1) [[0.96053898 0.46362575 0.00405893]] [0.96246391]
# test x,y and train x, y shape :  (2048, 1, 3) (2048, 1) (7936, 1, 3) (7936, 1)
#
# Epoch 00001: loss improved from inf to 0.05077, saving model to best_model.h5
#
# Epoch 00002: loss improved from 0.05077 to 0.02782, saving model to best_model.h5
#
# Epoch 00003: loss did not improve from 0.02782
#
# Epoch 00004: loss did not improve from 0.02782
#
# Epoch 00005: loss did not improve from 0.02782
#
# Epoch 00006: loss did not improve from 0.02782
#
# Epoch 00007: loss did not improve from 0.02782
#
# Epoch 00008: loss did not improve from 0.02782
#
# Epoch 00009: loss did not improve from 0.02782
#
# Epoch 00010: loss improved from 0.02782 to 0.01738, saving model to best_model.h5
#
# Epoch 00011: loss improved from 0.01738 to 0.00758, saving model to best_model.h5
#
# Epoch 00012: loss improved from 0.00758 to 0.00247, saving model to best_model.h5
#
# Epoch 00013: loss improved from 0.00247 to 0.00134, saving model to best_model.h5
#
# Epoch 00014: loss improved from 0.00134 to 0.00107, saving model to best_model.h5
#
# Epoch 00015: loss improved from 0.00107 to 0.00095, saving model to best_model.h5
#
# Epoch 00016: loss improved from 0.00095 to 0.00082, saving model to best_model.h5
#
# Epoch 00017: loss improved from 0.00082 to 0.00075, saving model to best_model.h5
#
# Epoch 00018: loss improved from 0.00075 to 0.00063, saving model to best_model.h5
#
# Epoch 00019: loss improved from 0.00063 to 0.00061, saving model to best_model.h5
#
# Epoch 00020: loss improved from 0.00061 to 0.00056, saving model to best_model.h5
#
# Epoch 00021: loss improved from 0.00056 to 0.00055, saving model to best_model.h5
#
# Epoch 00022: loss improved from 0.00055 to 0.00051, saving model to best_model.h5
#
# Epoch 00023: loss improved from 0.00051 to 0.00046, saving model to best_model.h5
#
# Epoch 00024: loss did not improve from 0.00046
#
# Epoch 00025: loss did not improve from 0.00046
#
# Epoch 00026: loss improved from 0.00046 to 0.00044, saving model to best_model.h5
#
# Epoch 00027: loss improved from 0.00044 to 0.00042, saving model to best_model.h5
#
# Epoch 00028: loss did not improve from 0.00042
#
# Epoch 00029: loss did not improve from 0.00042
#
# Epoch 00030: loss improved from 0.00042 to 0.00039, saving model to best_model.h5
#
# Epoch 00031: loss did not improve from 0.00039
#
# Epoch 00032: loss improved from 0.00039 to 0.00035, saving model to best_model.h5
#
# Epoch 00033: loss did not improve from 0.00035
#
# Epoch 00034: loss did not improve from 0.00035
#
# Epoch 00035: loss did not improve from 0.00035
#
# Epoch 00036: loss did not improve from 0.00035
#
# Epoch 00037: loss improved from 0.00035 to 0.00032, saving model to best_model.h5
#
# Epoch 00038: loss did not improve from 0.00032
#
# Epoch 00039: loss did not improve from 0.00032
#
# Epoch 00040: loss did not improve from 0.00032
#
# Epoch 00041: loss did not improve from 0.00032
#
# Epoch 00042: loss improved from 0.00032 to 0.00030, saving model to best_model.h5
#
# Epoch 00043: loss did not improve from 0.00030
#
# Epoch 00044: loss did not improve from 0.00030
#
# Epoch 00045: loss improved from 0.00030 to 0.00029, saving model to best_model.h5
#
# Epoch 00046: loss did not improve from 0.00029
#
# Epoch 00047: loss did not improve from 0.00029
#
# Epoch 00048: loss did not improve from 0.00029
#
# Epoch 00049: loss did not improve from 0.00029
#
# Epoch 00050: loss did not improve from 0.00029
#
# Epoch 00051: loss did not improve from 0.00029
#
# Epoch 00052: loss did not improve from 0.00029
#
# Epoch 00053: loss did not improve from 0.00029
#
# Epoch 00054: loss did not improve from 0.00029
#
# Epoch 00055: loss did not improve from 0.00029
#
# Epoch 00056: loss did not improve from 0.00029
#
# Epoch 00057: loss did not improve from 0.00029
#
# Epoch 00058: loss did not improve from 0.00029
#
# Epoch 00059: loss did not improve from 0.00029
#
# Epoch 00060: loss did not improve from 0.00029
#
# Epoch 00061: loss did not improve from 0.00029
#
# Epoch 00062: loss did not improve from 0.00029
#
# Epoch 00063: loss did not improve from 0.00029
#
# Epoch 00064: loss did not improve from 0.00029
#
# Epoch 00065: loss did not improve from 0.00029
#
# Epoch 00066: loss did not improve from 0.00029
#
# Epoch 00067: loss did not improve from 0.00029
#
# Epoch 00068: loss did not improve from 0.00029
#
# Epoch 00069: loss did not improve from 0.00029
#
# Epoch 00070: loss did not improve from 0.00029
#
# Epoch 00071: loss did not improve from 0.00029
#
# Epoch 00072: loss did not improve from 0.00029
#
# Epoch 00073: loss did not improve from 0.00029
#
# Epoch 00074: loss did not improve from 0.00029
#
# Epoch 00075: loss did not improve from 0.00029
#
# Epoch 00076: loss did not improve from 0.00029
#
# Epoch 00077: loss did not improve from 0.00029
#
# Epoch 00078: loss did not improve from 0.00029
#
# Epoch 00079: loss did not improve from 0.00029
#
# Epoch 00080: loss did not improve from 0.00029

# %%
# Save entire model to a HDF5 file
model.save('my_model.h5')

# Recreate the exact same model, including weights and optimizer.
model = tf.keras.models.load_model('my_model.h5')

# %%
model

# %%
batch_size=64
pred = model.predict(test_X, batch_size=batch_size)
loss_and_metrics = model.evaluate(test_X,test_y, batch_size=batch_size)
loss_and_metrics
# Out:
# 2048/2048 [==============================] - 1s 304us/sample - loss: 0.0016 - mean_absolute_error: 0.0388
# [0.0015629630579496734, 0.038849887]

# %%
'''epoch = 80 
feature = price,pct,vol
'''
df_yp=plot_graph(model,pred,test_y)
# Out:
# minumum loss: 0.01716032704073791
# at epoch : (array([44]),)
#                 p           y        diff
# count  200.000000  200.000000  200.000000
# mean   929.749084  929.045750   -0.703219
# std      7.588904    6.839471    1.361723
# min    912.967224  913.350000   -4.105371
# 25%    922.774307  922.950000   -1.692603
# 50%    930.666931  930.000000   -0.824188
# 75%    934.938828  933.412500    0.104752
# max    944.505371  942.550000    4.863000

# %%
'''
where did the best_model.h5 file got saved
'''
# Out:
# '\nwhere did the best_model.h5 file got saved\n'

# %%
best_model = tf.keras.models.load_model('best_model.h5')
batch_size=64
pred = best_model.predict(test_X, batch_size=batch_size)
loss_and_metrics = best_model.evaluate(test_X,test_y, batch_size=batch_size)
loss_and_metrics
# Out:
# 2048/2048 [==============================] - 1s 278us/sample - loss: 8.3780e-05 - mean_absolute_error: 0.0068
# [8.377967785122564e-05, 0.0068466635]

# %%
df_yp=plot_graph(best_model,pred,test_y,best_model_bool=True)
# Out:
#                 p           y        diff
# count  200.000000  200.000000  200.000000
# mean   929.455933  929.045750   -0.410360
# std      7.485439    6.839471    1.286166
# min    913.238037  913.350000   -3.557910
# 25%    922.314026  922.950000   -1.320337
# 50%    930.678650  930.000000   -0.641827
# 75%    934.441208  933.412500    0.289032
# max    943.057495  942.550000    5.509241

# %%
from scipy import stats
print(stats.describe(test_y))
print(stats.describe(pred))
data={'test_y':list(test_y.reshape(-1)),'pred':list(pred.reshape(-1))}
df_test = pd.DataFrame(data)
print(df_test.describe())
# Out:
# DescribeResult(nobs=2048, minmax=(array([0.07459095]), array([0.41915303])), mean=array([0.27884619]), variance=array([0.0031193]), skewness=array([-0.29350811]), kurtosis=array([0.57865444]))
# DescribeResult(nobs=2048, minmax=(array([0.07351419], dtype=float32), array([0.41376317], dtype=float32)), mean=array([0.28532305], dtype=float32), variance=array([0.00300856], dtype=float32), skewness=array([-0.47359857], dtype=float32), kurtosis=array([0.97028494], dtype=float32))
#             test_y         pred
# count  2048.000000  2048.000000
# mean      0.278846     0.285323
# std       0.055851     0.054850
# min       0.074591     0.073514
# 25%       0.253609     0.261427
# 50%       0.282964     0.288964
# 75%       0.306545     0.313396
# max       0.419153     0.413763

# %%
# mse, _ = model.evaluate(test_X,test_y, batch_size=batch_size)
rmse = np.sqrt(loss_and_metrics[0])
print('Root Mean Square Error on test set: {}'.format(round(rmse, 3)))
# Out:
# Root Mean Square Error on test set: 0.009

# %%
'''===================================================end of session===================================================='''
'''================================below is rough work============================='''
